# %% [markdown]
# #  프롬프트 엔지니어링 - 효과적인 프롬프트 템플릿 설계
#
# ### **학습 목표:**  효과적인 프롬프트 템플릿의 기본 구조와 설계 원칙을 이해한다
#
# ### 필수 패키지 설치
# ```bash
# uv add langchain-openai langchain-core python-dotenv defusedxml
# ```
#
# ### 환경 변수 설정
# 프로젝트 루트에 `.env` 파일을 생성하고 다음과 같이 OpenAI API 키를 설정합니다:
# ```
# OPENAI_API_KEY=your_api_key_here
# ```
#
# ---

# %% [markdown]
# # 환경 설정 및 준비

# %% [markdown]
# `(1) Env 환경변수`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# google colab에서 실습 시
# from google.colab import userdata
# import os

# OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
# os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %% [markdown]
# `(2) 기본 라이브러리`

# %%
import os
from glob import glob

from pprint import pprint
import json

# %% [markdown]
# `(3) LLM 설정`

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model='gpt-4.1-nano',
    temperature=0.3,
    top_p=0.9,
)

# %% [markdown]
# ---
# # **프롬프트 유형**
#
# - 종류: 질문형, 지시형, 대화형, 조건부, 예시 기반 등
# - 이러한 프롬프트 유형들은 상황에 따라 조합하여 사용 가능
# - 목적에 맞는 적절한 유형을 선택하는 것이 중요

# %% [markdown]
# `(1) 질문형 프롬프트 (Question Prompts)`
#    - 정보 추출에 효과적
#    - 구체적인 답변 유도 가능

# %%
from langchain_core.prompts import PromptTemplate

# 단순 질문형
question_prompt = PromptTemplate(
    template="다음 주제에 대해 무엇을 알고 있나요?: {topic}",
    input_variables=["topic"]
)

# LCEL chain 구성
chain = question_prompt | llm

# 질문
topic = "양자 컴퓨팅"
output = chain.invoke({"topic": topic})
pprint(output.content)
# Out:
# ('양자 컴퓨팅(Quantum Computing)은 양자역학의 원리를 이용하여 정보를 처리하는 계산 방식입니다. 기존의 고전 컴퓨터는 '
#  '비트(0 또는 1)를 사용하지만, 양자 컴퓨터는 큐비트(Quantum Bit 또는 Qubit)를 사용하여 동시에 여러 상태를 가질 수 '
#  '있는 병렬 처리가 가능합니다.\n'
#  '\n'
#  '주요 개념 및 특징:\n'
#  '1. **큐비트 (Qubit):** 양자 상태를 나타내는 기본 단위로, 0과 1의 중첩(superposition) 상태를 가질 수 '
#  '있습니다.\n'
#  '2. **중첩 (Superposition):** 큐비트가 여러 상태를 동시에 가질 수 있는 특성으로, 병렬 계산 능력을 제공합니다.\n'
#  '3. **얽힘 (Entanglement):** 두 개 이상의 큐비트가 서로 강하게 연결되어 있어 한 큐비트의 상태가 다른 큐비트의 상태에 '
#  '즉각적으로 영향을 미치는 현상입니다.\n'
#  '4. **양자 게이트:** 큐비트의 상태를 변화시키는 연산자로, 양자 알고리즘의 핵심입니다.\n'
#  '5. **양자 알고리즘:** 쇼어 알고리즘(소인수 분해), 그로버 알고리즘(데이터 검색) 등 특정 문제를 고전 컴퓨터보다 훨씬 빠르게 '
#  '해결할 수 있는 알고리즘이 개발되고 있습니다.\n'
#  '\n'
#  '장점과 도전 과제:\n'
#  '- **장점:** 특정 계산 문제에서 고전 컴퓨터보다 훨씬 빠른 속도와 효율성을 기대할 수 있습니다.\n'
#  '- **도전 과제:** 큐비트의 안정성(코히런스 유지), 오류 수정, 확장성, 실용적 하드웨어 개발 등이 아직 해결해야 할 과제입니다.\n'
#  '\n'
#  '응용 분야:\n'
#  '- 암호 해독\n'
#  '- 분자 및 재료 과학 시뮬레이션\n'
#  '- 최적화 문제\n'
#  '- 인공지능 및 머신러닝\n'
#  '\n'
#  '현재 양자 컴퓨팅은 연구 단계에 있으며, 구글, IBM, D-Wave, 페이스북 등 여러 기업과 연구기관이 발전을 위해 노력하고 '
#  '있습니다. 그러나 실용적이고 대규모 양자 컴퓨터가 상용화되기까지는 시간이 더 필요할 것으로 예상됩니다.')

# %%
### from_template 메소드를 사용한 방법

from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from pprint import pprint

# from_template을 사용한 PromptTemplate 생성
question_template = "다음 주제에 대해 무엇을 알고 있나요?: {topic}"
question_prompt = PromptTemplate.from_template(question_template)

# LCEL chain 구성
chain = question_prompt | llm

# 질문 실행
topic = "양자 컴퓨팅"
output = chain.invoke({"topic": topic})
pprint(output.content)
# Out:
# ('양자 컴퓨팅(Quantum Computing)은 양자역학의 원리를 이용하여 정보를 처리하는 컴퓨팅 기술입니다. 기존의 고전 컴퓨터가 '
#  '비트(0 또는 1)를 사용하여 데이터를 처리하는 반면, 양자 컴퓨터는 양자 비트(큐비트, qubit)를 사용합니다. 큐비트는 동시에 여러 '
#  '상태를 가질 수 있는 슈퍼포지션(superposition) 특성을 가지고 있어, 특정 계산을 훨씬 빠르게 수행할 수 있습니다.\n'
#  '\n'
#  '양자 컴퓨팅의 핵심 원리에는 다음과 같은 것들이 있습니다:\n'
#  '\n'
#  '1. 슈퍼포지션(Superposition): 큐비트는 0과 1의 상태를 동시에 가질 수 있어, 병렬로 여러 계산을 수행할 수 있습니다.\n'
#  '2. 얽힘(Entanglement): 두 개 이상의 큐비트가 서로 강하게 연결되어 있어, 하나의 상태 변화가 다른 큐비트의 상태에 '
#  '즉각적인 영향을 미칩니다.\n'
#  '3. 양자 간섭(Quantum Interference): 여러 계산 경로를 결합하여 원하는 결과를 증폭시키거나 방해하는 방식으로 계산 '
#  '효율을 높입니다.\n'
#  '\n'
#  '양자 컴퓨팅은 암호 해독, 최적화 문제, 분자 및 재료의 양자 시뮬레이션, 머신러닝 등 다양한 분야에서 혁신적인 응용 가능성을 가지고 '
#  '있습니다. 그러나 아직 기술적 난제도 많아, 안정적인 큐비트 유지, 오류 수정, 확장성 확보 등이 연구의 핵심 과제입니다.\n'
#  '\n'
#  '현재 구글, IBM, 페이스북 등 여러 기업과 연구기관들이 양자 컴퓨팅 기술을 개발 중이며, 일부는 이미 실험적 수준의 양자 프로세서를 '
#  '선보이고 있습니다. 하지만 상용화와 실질적 활용에는 아직 시간이 더 필요하다고 평가되고 있습니다.')

# %% [markdown]
# **[참고]** `from_template` 방식의 장점:
# - 코드가 더 간결해진다
# - 입력 변수를 수동으로 지정할 필요가 없다
# - 템플릿에서 사용된 변수를 자동으로 추출한다

# %%
# 분석 질문형 
analysis_prompt = PromptTemplate(
    template="""다음 텍스트에서 주요 논점은 무엇인가요? 세 가지로 설명해주세요.

    [텍스트]
    {text}

    [답변]
    """,
    input_variables=["text"]
)

# LCEL
chain = analysis_prompt | llm

# 질문
text = """양자 컴퓨팅은 양자역학의 원리를 이용하여 정보를 처리하는 컴퓨팅 기술이다. 
양자 컴퓨팅은 전통적인 컴퓨팅과는 다르게 양자역학의 원리를 이용하여 정보를 처리한다. 
양자 컴퓨팅은 양자역학의 원리를 이용하여 정보를 처리하는 컴퓨팅 기술이다.
"""

output = chain.invoke({"text": text})
pprint(output.content)
# Out:
# ('1. 양자 컴퓨팅은 양자역학의 원리를 기반으로 하는 새로운 정보 처리 기술이다.  \n'
#  '2. 기존의 전통적인 컴퓨팅과는 달리, 양자 컴퓨팅은 양자역학의 특성을 활용하여 정보를 처리한다.  \n'
#  '3. 양자 컴퓨팅은 기존 컴퓨팅 방식과 차별화된 기술로서, 양자역학의 원리를 이용하는 것이 핵심이다.')

# %% [markdown]
# ### **[실습 1]**
#
# - 앞의 예제를 from_template 메소드를 사용하는 방식으로 구현하세요.

# %%
# 여기에 코드를 작성하세요.

question_template = """다음 텍스트에서 주요 논점은 무엇인가요? 세 가지로 설명해주세요.

    [텍스트]
    {text}

    [답변]
    """

question_prompt = PromptTemplate.from_template(question_template)

# LCEL chain 구성
chain = question_prompt | llm

# 질문 실행
text = """양자 컴퓨팅은 양자역학의 원리를 이용하여 정보를 처리하는 컴퓨팅 기술이다. 
양자 컴퓨팅은 전통적인 컴퓨팅과는 다르게 양자역학의 원리를 이용하여 정보를 처리한다. 
양자 컴퓨팅은 양자역학의 원리를 이용하여 정보를 처리하는 컴퓨팅 기술이다.
"""
output = chain.invoke({"text": text})
print(type(output))     # <class 'langchain_core.messages.ai.AIMessage'> -> 단순 출력 확인(실습, 디버깅)
pprint(output.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# ('1. 양자 컴퓨팅은 양자역학의 원리를 기반으로 하는 새로운 정보 처리 기술임을 강조한다.  \n'
#  '2. 기존의 전통적 컴퓨팅과는 달리, 양자 컴퓨팅은 양자역학의 원리를 활용하여 정보를 처리한다는 점이 주요 논점이다.  \n'
#  '3. 텍스트는 양자 컴퓨팅이 기존 컴퓨팅 방식과 차별화된 기술임을 반복하여 설명하고 있다.')

# %% [markdown]
# `(2) 지시형 프롬프트 (Instruction Prompts)`
#    - 명확한 작업 수행 지시
#    - 단계별 처리 가능

# %%
from langchain_core.output_parsers import StrOutputParser
# 작업 지시형
task_prompt = PromptTemplate(
    template="다음 텍스트를 한국어로 번역하세요:\n\n[텍스트]\n{text}",
    input_variables=["text"]
)

# LCEL
chain = task_prompt | llm | StrOutputParser() # StrOutputParser() = LLM의 출력(AIMessage 객체)에서 텍스트만 추출해주는 파서 -> 다음 처리에 문자열로 전달(체인 연결, 저장 등)

# 질문
text = "Quantum computing is a computing technology that uses the principles of quantum mechanics to process information."
output = chain.invoke({"text": text})
print(type(output))     # <class 'str'>
pprint(output)
# Out:
# <class 'str'>
# '양자 컴퓨팅은 양자 역학의 원리를 이용하여 정보를 처리하는 컴퓨팅 기술입니다.'

# %%
# 단계별 지시형
step_prompt = PromptTemplate(
    template="""다음 텍스트에 대해서 작업을 순서대로 수행하세요:

    [텍스트]
    {text}

    [작업 순서]
    1. 텍스트를 1문장으로 요약
    2. 핵심 키워드 3개 추출
    3. 감정 분석 수행(긍정/부정/중립)

    [작업 결과]
    """,
    input_variables=["text"]
)

# LCEL
chain = step_prompt | llm | StrOutputParser()

# 질문
text = """
양자 컴퓨팅은 양자역학의 원리를 바탕으로 데이터를 처리하는 새로운 형태의 계산 방식이다. 
기존의 고전적 컴퓨터는 0과 1로 이루어진 이진법(bit)을 사용하여 데이터를 처리하지만, 
양자 컴퓨터는 양자 비트(큐비트, qubit)를 사용하여 훨씬 더 복잡하고 빠른 계산을 수행할 수 있다. 

큐비트는 동시에 0과 1의 상태를 가질 수 있는 양자 중첩(superposition) 상태를 활용하며, 
이를 통해 병렬 계산과 같은 고급 기능이 가능하다.
""" 

output = chain.invoke({"text": text})
pprint(output)
# Out:
# ('1. 양자 컴퓨팅은 양자역학 원리를 이용하여 큐비트의 중첩 상태를 활용해 고속 병렬 계산이 가능한 새로운 계산 방식이다.\n'
#  '\n'
#  '2. 핵심 키워드: 양자 컴퓨팅, 큐비트, 중첩\n'
#  '\n'
#  '3. 감정 분석: 중립')

# %% [markdown]
# ### **[실습 2]**
#
# - 두 개의 문장을 입력받아서, 두 문장의 맥락이 일치하는지 여부를 비교 분석하는 체인을 구성하세요.
# - PromptTemplate를 사용하고, 두 문장을 입력받을 수 있도록 합니다.
# - 단계별 지시형 프롬프트로 작성합니다.

# %%
# 여기에 코드를 작성하세요.
# 작업 지시형
task_prompt = PromptTemplate(
    template="""다음 두 개의 문장에 대해서 분석을 순서대로 수행하세요:

    [문장1]
    {sentence1}
    
    [문장2]
    {sentence2}

    [분석 순서]
    1. 문장1의 맥락 파악
    2. 문장2의 맥락 파악
    3. 1~2단계에서 파악한 맥락 비교
    4. 3단계에서 비교한 결과(문장1과 문장2의 맥락)가 일치하는지 판단
    5. 4단계에서 판단한 근거를 설명

    [분석 결과 형식]
    문장1의 맥락:
    문장2의 맥락:
    문장1과 문장2의 맥락 비교:
    일치 여부 판단:
    판단 근거 설명: 
    """,
    input_variables=["sentence1", "sentence2"]
)

# LCEL
chain = task_prompt | llm | StrOutputParser()

# 질문
sentence1 = "트롬은 아기 곰이다."
sentence2 = "트롬곰은 LG Tromm의 마스코트이다."
output = chain.invoke({"sentence1": sentence1, "sentence2": sentence2})
pprint(output)
# Out:
# ('문장1의 맥락:\n'
#  '"트롬은 아기 곰이다."라는 문장은 트롬이라는 존재가 아기 곰이라는 동물 또는 캐릭터임을 나타내며, 친근하고 귀여운 이미지 또는 동물적 '
#  '특성을 갖고 있다는 맥락을 전달합니다. 이는 트롬이 실제 곰일 수도 있고, 캐릭터 또는 마스코트로서의 성격을 지니고 있을 가능성을 '
#  '내포합니다.\n'
#  '\n'
#  '문장2의 맥락:\n'
#  '"트롬곰은 LG Tromm의 마스코트이다."라는 문장은 트롬곰이라는 캐릭터 또는 인물이 LG의 가전 브랜드인 Tromm의 대표 '
#  '마스코트임을 설명합니다. 이는 트롬곰이 브랜드 홍보를 위해 만들어진 캐릭터임을 의미하며, 브랜드와 연관된 마스코트라는 맥락을 '
#  '전달합니다.\n'
#  '\n'
#  '문장1과 문장2의 맥락 비교:\n'
#  '첫 번째 문장은 트롬이 아기 곰이라는 존재에 대해 일반적이고 친근한 이미지로 설명하는 반면, 두 번째 문장은 트롬곰이 특정 브랜드의 '
#  "마스코트임을 구체적으로 지칭합니다. 두 문장 모두 '트롬' 또는 '트롬곰'이 곰과 관련된 캐릭터임을 암시하지만, 문장1은 자연적 또는 "
#  '일반적 의미에 초점을 두고 있고, 문장2는 특정 브랜드와의 연관성을 강조합니다.\n'
#  '\n'
#  '일치 여부 판단:\n'
#  '일치하지 않는다.\n'
#  '\n'
#  '판단 근거 설명:\n'
#  '문장1은 "아기 곰"이라는 표현을 통해 트롬이 자연적 또는 일반적인 곰 캐릭터임을 암시하는 반면, 문장2는 "LG Tromm의 '
#  '마스코트"라는 구체적인 브랜드 관련 정보를 제공하여, 트롬곰이 브랜드 홍보용 캐릭터임을 명확히 하고 있습니다. 따라서 두 문장은 트롬이 '
#  '곰과 관련된 캐릭터라는 점은 공통적이지만, 하나는 자연적/일반적 의미이고, 다른 하나는 특정 브랜드와 연관된 의미로서 맥락이 다르기 '
#  '때문에 일치하지 않는다고 판단됩니다.')

# %%
# 강사님 예시
from langchain_core.prompts import PromptTemplate

# 프롬프트 템플릿 정의
context_prompt = PromptTemplate(
    template="""다음 두 문장의 맥락 일치성을 분석해주세요:

    [문장 1]
    {sentence1}

    [문장 2]
    {sentence2}

    [분석 단계]
    1. 각 문장의 주요 주제 파악
    2. 핵심 키워드 비교
    3. 문맥적 연관성 분석
    4. 일치성 점수 산출 (0-100%)

    [분석 결과 형식]
    주제 분석:
    키워드 비교:
    맥락 분석:
    일치성 점수:
    최종 판단: (일치/불일치)
    """,
    input_variables=["sentence1", "sentence2"]
)

# LCEL chain 구성
chain = context_prompt | llm

# 테스트 문장
sentence1 = "인공지능은 데이터를 기반으로 학습합니다."
sentence2 = "머신러닝 알고리즘은 데이터셋을 통해 패턴을 학습합니다."

# 질문 실행
output = chain.invoke({"sentence1": sentence1, "sentence2": sentence2})
pprint(output.content)
# Out:
# ('1. 각 문장의 주요 주제 파악  \n'
#  '- 문장 1: 인공지능이 데이터를 기반으로 학습하는 과정에 대한 설명  \n'
#  '- 문장 2: 머신러닝 알고리즘이 데이터셋을 통해 패턴을 학습하는 구체적 과정에 대한 설명  \n'
#  '\n'
#  '2. 핵심 키워드 비교  \n'
#  '- 문장 1: 인공지능, 데이터, 학습  \n'
#  '- 문장 2: 머신러닝 알고리즘, 데이터셋, 패턴, 학습  \n'
#  '\n'
#  '3. 문맥적 연관성 분석  \n'
#  '- 두 문장은 모두 "학습"이 핵심 개념이며, 데이터(데이터셋) 기반으로 패턴을 찾는 과정을 설명하고 있음.  \n'
#  '- 문장 1은 인공지능의 일반적인 학습 원리와 데이터 기반임을 언급하는 반면, 문장 2는 머신러닝 알고리즘의 구체적 학습 방법(패턴 '
#  '학습)을 설명.  \n'
#  '- 머신러닝은 인공지능의 한 분야이기 때문에, 두 문장은 기술적 맥락에서 밀접하게 연결되어 있음.  \n'
#  '\n'
#  '4. 일치성 점수 산출 (0-100%)  \n'
#  '- 두 문장은 인공지능과 머신러닝이 데이터 기반 학습을 수행한다는 점에서 핵심 개념이 일치하며, 내용이 상호 보완적임.  \n'
#  '- 다만, 문장 1은 일반적인 인공지능의 개념을, 문장 2는 머신러닝의 구체적 방법을 설명하므로, 세부 내용 차이도 존재함.  \n'
#  '\n'
#  '**계산:**  \n'
#  '일반적 개념과 구체적 방법이 모두 포함되어 있어 높은 일치성을 보임.  \n'
#  '적절한 가중치를 고려하여 85% 정도로 평가 가능.  \n'
#  '\n'
#  '**최종 판단:** 일치')

# %% [markdown]
# `(3) 대화형 프롬프트 (Conversational Prompts)`
#    - 자연스러운 상호작용
#    - 문맥 유지 가능
#
# cf. ChatPromptTemplate = system/human/ai 역할 구분

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# ChatPromptTemplate 객체를 직접 생성 (메시지 리스트, 입력 변수 리스트)
chat_prompt = ChatPromptTemplate(
    messages=[
        ("system", "당신은 무뚝뚝한 고객 서비스 담당자입니다."), # 친절한, 시니컬한, 무뚝뚝한
        ("human", "{customer_message}")
    ],
    input_variables=["customer_message"]
)

# LCEL chain 구성
chain = chat_prompt | llm | StrOutputParser()

# 질문 실행
customer_message = "안녕하세요. 제품 배송 문제로 연락드렸어요."
output = chain.invoke({"customer_message": customer_message})
pprint(output)
# Out:
# '무슨 문제인지 구체적으로 말씀해 주시겠어요?'

# %%
from langchain_core.prompts import ChatPromptTemplate

# from_messages 메소드를 사용한 ChatPromptTemplate 생성
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 친절한 고객 서비스 담당자입니다."),
    ("human", "{customer_message}"),
])

# LCEL
chain = chat_prompt | llm | StrOutputParser()

# 질문
customer_message = "안녕하세요. 제품 배송 문제로 연락드렸어요."
output = chain.invoke({"customer_message": customer_message})
pprint(output)
# Out:
# ('안녕하세요. 고객님께 불편을 드려 정말 죄송합니다. 배송 관련 문제를 도와드리기 위해 어떤 문제가 있으신지 자세히 말씀해 주실 수 '
#  '있을까요? 빠르게 해결해 드리도록 하겠습니다.')

# %%
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate

# 메시지 템플릿 사용
chat_prompt = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(
        "당신은 친절한 고객 서비스 담당자입니다."
    ),
    HumanMessagePromptTemplate.from_template(
        "{customer_message}"
    )
])

# LCEL
chain = chat_prompt | llm | StrOutputParser()

# 질문
customer_message = "안녕하세요. 제품 배송 문제로 연락드렸어요."
output = chain.invoke({"customer_message": customer_message})
pprint(output)
# Out:
# ('안녕하세요. 고객님께 불편을 드려 죄송합니다. 배송 관련 문제에 대해 도와드리기 위해 어떤 문제가 있으신지 상세히 알려주실 수 있을까요? '
#  '빠르게 해결해 드리겠습니다.')

# %% [markdown]
# ### **[실습 3]**
#
# - 상품 리뷰를 분석하는 AI 체인을 대화형 프롬프트로 구성합니다.
# - 메시지 템플릿을 사용하여 메시지 역할을 구분합니다.

# %%
# 예시 리뷰
reviews = [
    "이 블루투스 이어폰 정말 만족스러워요! 음질도 좋고 배터리도 오래가요. 다만 케이스가 좀 큰 감이 있네요.",
    "배송은 빨랐는데 제품 품질이 기대에 못 미쳐요. 터치감이 둔하고 연결이 자주 끊깁니다. 가성비 생각하면 그냥 쓸만하네요.",
    "가격대비 괜찮은 것 같아요. 디자인도 깔끔하고 기본적인 기능은 다 갖췄네요. 추천합니다!"
]

# %%
# 여기에 코드를 작성하세요.
review_prompt = ChatPromptTemplate.from_messages([
    ("system", """당신은 상품 리뷰 분석 전문가입니다.
    상품 리뷰 분석 시 반드시 다음 단계를 순서대로 수행하세요:
    1. 리뷰 대상 키워드 추출
    2. 감정/판단 키워드 추출
    3. 2단계에서 추출한 감정/판단 키워드(들) 종합해서 해당 리뷰의 전반적인 sentiment(긍정/부정/중립) 판단
    4. 3단계 종합 sentiment 판단을 통해 1~5점 중 별점 예측
    5. 1~2단계에서 추출한 키워드를 이용하여 리뷰 전체를 한 문장으로 요약

    [분석 결과 형식]
    리뷰 대상 키워드:
    감정/판단 키워드:
    sentiment:
    예상 별점:
    요약:
    """),
    ("human", "다음 상품 리뷰를 분석해 주세요:\n\n{review}"),
])

# LCEL
review_chain = review_prompt | llm | StrOutputParser()

# 각 리뷰 분석 실행
for idx, review in enumerate(reviews, 1):
    print(f"\n=== 리뷰 {idx} 분석 결과 ===")
    result = review_chain.invoke({"review": review})
    print(result)
# Out:
# === 리뷰 1 분석 결과 ===
# 리뷰 대상 키워드:
#     블루투스 이어폰, 음질, 배터리, 케이스
#     감정/판단 키워드:
#     만족스러워요, 좋고, 오래가요, 좀 큰
#     sentiment:
#     긍정적
#     예상 별점:
#     4점
#     요약:
#     블루투스 이어폰의 음질과 배터리 성능이 뛰어나지만 케이스 크기가 다소 아쉽다는 리뷰입니다.
#
# === 리뷰 2 분석 결과 ===
# 리뷰 대상 키워드:
#     배송, 제품 품질, 터치감, 연결, 가성비
#     감정/판단 키워드:
#     빨랐는데, 기대에 못 미쳐요, 둔하고, 자주 끊깁니다, 쓸만하네요
#     sentiment:
#     부정적
#     예상 별점:
#     2점
#     요약:
#     배송은 빠르지만 제품 품질과 연결 문제가 있어 전반적으로 만족스럽지 않다
#
# === 리뷰 3 분석 결과 ===
# 리뷰 대상 키워드: 가격, 디자인, 기능, 추천
# 감정/판단 키워드: 괜찮은, 깔끔한, 추천
# sentiment: 긍정
# 예상 별점: 4점
# 요약: 가격 대비 디자인과 기능이 만족스럽고 추천할 만한 상품입니다.

# %%
# 강사님 예시
# # 리뷰 분석 템플릿 생성
review_prompt = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(
        "당신은 상품 리뷰 분석 전문가입니다. 리뷰의 감정과 주요 포인트를 분석합니다."
        ),
    HumanMessagePromptTemplate.from_template(
        "다음 리뷰를 분석해주세요: {review}"
        )
])

# LCEL
review_chain = review_prompt | llm | StrOutputParser()

# 각 리뷰 분석 실행
for idx, review in enumerate(reviews, 1):
    print(f"\n=== 리뷰 {idx} 분석 결과 ===")
    result = review_chain.invoke({"review": review})
    print(result)
# Out:
# === 리뷰 1 분석 결과 ===
# 이 리뷰는 전반적으로 긍정적인 감정을 나타내고 있습니다. 사용자는 "정말 만족스럽다"라는 표현으로 제품에 대한 만족감을 드러내고 있으며, 특히 "음질도 좋고 배터리도 오래가요"라는 구체적인 장점을 언급하여 제품의 성능에 대한 긍정적인 평가를 하고 있습니다. 다만, 케이스 크기에 대한 약간의 아쉬움도 함께 표출되어 있어, 크기가 다소 크다는 점이 개선될 수 있는 부분임을 시사합니다. 종합적으로, 이 블루투스 이어폰은 음질과 배터리 성능이 뛰어나며, 크기만 조금 더 개선된다면 더욱 완벽한 제품이 될 것으로 보입니다.
#
# === 리뷰 2 분석 결과 ===
# 이 리뷰의 감정: 부정적
#
# 주요 포인트:
# 1. 배송이 빠름
# 2. 제품 품질이 기대에 미치지 못함
# 3. 터치감이 둔함
# 4. 연결이 자주 끊김
# 5. 가성비는 무난하다고 평가함
#
# === 리뷰 3 분석 결과 ===
# 이 리뷰의 감정: 긍정적
#
# 주요 포인트:
# 1. 가격 대비 만족도 높음
# 2. 디자인이 깔끔함
# 3. 기본 기능 모두 갖춤
# 4. 추천 의사 표현

# %% [markdown]
# `(4) 예시 기반 프롬프트 (Few-Shot Prompts)`
#    - 원하는 출력 형식 명확화
#    - 모델의 이해도 향상

# %%
few_shot_prompt = PromptTemplate(
    template="""다음은 텍스트를 요약하는 예시입니다:

원문: {example_input}
요약: {example_output}

이제 다음 텍스트를 같은 방식으로 50자 이내로 요약해주세요:
원문: {input_text}
요약:
""",
    input_variables=["example_input", "example_output", "input_text"]
)

# LCEL
chain = few_shot_prompt | llm | StrOutputParser()

# 예시 텍스트 
example_input = """인공지능(AI)은 인간의 학습능력, 추론능력, 지각능력, 자연언어의 이해능력 등을 
컴퓨터 프로그램으로 실현한 기술이다. 인공지능은 딥러닝, 기계학습 등 다양한 기술을 포함하며, 
최근에는 자율주행, 의료진단, 언어번역 등 다양한 분야에서 활용되고 있다."""

example_output = "인공지능: 인간의 학습능력, 추론능력, 지각능력 등을 컴퓨터 프로그램으로 실현한 기술"

# 입력 텍스트 
input_text = """양자 컴퓨팅은 양자역학의 원리를 활용하여 정보를 처리하는 혁신적인 컴퓨팅 기술이다. 
기존의 디지털 컴퓨터가 0과 1의 이진법을 사용하는 것과 달리, 양자 컴퓨터는 중첩 상태를 활용하여 
동시에 여러 계산을 수행할 수 있다. 이러한 특성으로 인해 특정 문제에서는 기존 컴퓨터보다 
월등히 빠른 처리 속도를 보여준다. 현재는 아직 초기 단계지만, 암호화, 신약 개발, 기후 모델링 등 
다양한 분야에서 혁신적인 발전이 기대된다."""

# 체인 실행
output = chain.invoke({
    "example_input": example_input, 
    "example_output": example_output, 
    "input_text": input_text
})
pprint(output)
# Out:
# '양자컴퓨팅: 양자역학 활용, 빠른 계산 기대하는 기술'

# %% [markdown]
# ### **[실습 4]**
#
# - [실습 3]의 상품 리뷰 분석 시스템의 입출력 형식을 예시로 추가해서 프롬프트를 작성합니다.
# - 체인을 실행하여 테스트합니다.

# %%
# 여기에 코드를 작성하세요.
review_few_shot_prompt = ChatPromptTemplate.from_messages([
    # 방법1
    ("system", """당신은 상품 리뷰 분석 전문가입니다.
    상품 리뷰 분석 시 반드시 다음 단계를 순서대로 수행하세요:
    1. 리뷰 대상 키워드 추출
    2. 감정/판단 키워드 추출
    3. 2단계에서 추출한 감정/판단 키워드(들) 종합해서 해당 리뷰의 전반적인 sentiment(긍정/부정/중립) 판단
    4. 3단계 종합 sentiment 판단을 통해 1~5점 중 별점 예측
    5. 1~2단계에서 추출한 키워드를 이용하여 리뷰 전체를 한 문장으로 요약

    [분석 결과 형식]
    리뷰 대상 키워드:
    감정/판단 키워드:
    sentiment:
    예상 별점:
    요약:

    다음은 상품 리뷰 분석 예시입니다:
    [예시 리뷰]
    {example_review}

    [예시 분석 결과]
    {example_output}
    """),
    ("human", "다음 상품 리뷰를 분석해 주세요:\n\n{review}"),

    # 방법2 = Few-Shot 예시(입력/출력 쌍) -> 실제 입력
    # ("human", "(예시) 다음 상품 리뷰를 분석해 주세요:\n\n{example_review}"),
    # ("ai",    example_output),
    # ("human", "(실제) 다음 상품 리뷰를 분석해 주세요:\n\n{review}"),
])

# LCEL
review_few_shot_chain = review_few_shot_prompt | llm | StrOutputParser()

example_review = "이 무선 마우스 정말 편해요! 클릭감도 좋고 배터리도 오래가요. 가격도 합리적이고 디자인도 깔끔합니다."
example_output = """
리뷰 대상 키워드: 무선 마우스, 클릭감, 배터리, 가격, 디자인
감정/판단 키워드: 편함, 좋음, 오래감, 합리적, 깔끔
sentiment: 긍정
예상 별점: 5점
요약: 클릭감, 배터리, 가격, 디자인 모두 만족스러운 무선 마우스
"""

# 각 리뷰 분석 실행
for idx, review in enumerate(reviews, 1):
    print(f"\n=== 리뷰 {idx} 분석 결과 ===")
    result = review_few_shot_chain.invoke({
        "review": review,
        "example_review": example_review,
        "example_output": example_output
        })
    print(result)
# Out:
# === 리뷰 1 분석 결과 ===
# 리뷰 대상 키워드: 블루투스 이어폰, 음질, 배터리, 케이스
# 감정/판단 키워드: 만족스러워요, 좋고, 오래가요, 좀 큰 감이 있다
# sentiment: 긍정
# 예상 별점: 4점
# 요약: 음질과 배터리 성능이 뛰어나지만 케이스 크기에 아쉬움이 있는 블루투스 이어폰
#
# === 리뷰 2 분석 결과 ===
# 리뷰 대상 키워드: 배송, 제품 품질, 터치감, 연결, 가성비
# 감정/판단 키워드: 빨랐음, 못 미침, 둔함, 자주 끊김, 쓸만함
# sentiment: 부정
# 예상 별점: 2점
# 요약: 빠른 배송이었지만 제품 품질과 연결 문제가 있어 가성비를 고려하면 만족스럽지 않은 상품
#
# === 리뷰 3 분석 결과 ===
# 리뷰 대상 키워드: 가격, 디자인, 기본적인 기능, 추천
# 감정/판단 키워드: 괜찮은, 깔끔한, 갖췄다, 추천
# sentiment: 긍정
# 예상 별점: 4점
# 요약: 가격 대비 디자인과 기능이 만족스럽고 추천할 만한 상품

# %% [markdown]
# `(5) 조건부 프롬프트 (Conditional Prompts)`
#    - 상황별 다른 처리
#    - 유연한 응답 생성

# %%
# 조건부 프롬프트 템플릿 정의 (입력 텍스트에 따라 작업 유형을 지정)
conditional_prompt = PromptTemplate(
    template="""입력 텍스트: {text}

주어진 텍스트가 질문인 경우: 명확한 답변을 제공
주어진 텍스트가 진술문인 경우: 진술문의 사실 여부를 검증
주어진 텍스트가 요청사항인 경우: 수행 방법을 단계별로 설명

응답은 다음 형식을 따라주세요:
유형: [질문/진술문/요청사항]
내용: [상세 응답]""",
    input_variables=["text"]
)

# LCEL 체인 구성
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0) # 모델별로 비교해보면 좋을 듯
chain = conditional_prompt | llm | StrOutputParser()

# %%
# 질문형 테스트
response = chain.invoke({
    "text": "인공지능은 인간의 일자리를 모두 대체하게 될까요?",
})
print(response)
# Out:
# 유형: 질문
# 내용: 인공지능이 인간의 일자리를 모두 대체할 가능성은 매우 낮습니다. 인공지능은 반복적이고 규칙 기반의 작업을 자동화하는 데 뛰어나지만, 창의성, 감정적 지능, 복잡한 의사결정 등 인간 고유의 능력을 완전히 대체하기는 어렵습니다. 또한, 인공지능의 발전은 새로운 일자리와 산업을 창출할 가능성도 큽니다. 따라서 인공지능은 일부 직업을 변화시키거나 대체할 수 있지만, 모든 일자리를 대체하는 것은 현실적으로 불가능하며, 인간과 인공지능이 협력하는 형태로 일자리 환경이 변화할 것으로 예상됩니다.

# %%
# 진술문 테스트
response = chain.invoke({
    "text": "양자컴퓨터는 현재 모든 암호화 시스템을 무력화할 수 있다."
})
print(response)
# Out:
# 유형: 진술문
# 내용: "양자컴퓨터는 현재 모든 암호화 시스템을 무력화할 수 있다"는 진술은 사실이 아닙니다. 현재의 양자컴퓨터 기술은 아직 초기 단계에 있으며, 모든 암호화 시스템을 무력화할 만큼 강력하지 않습니다. 특히, 널리 사용되는 RSA나 ECC 같은 공개키 암호는 양자컴퓨터의 발전에 따라 위험에 처할 수 있지만, 현재 상용화된 양자컴퓨터는 이러한 암호를 깨기에는 계산 능력이 부족합니다. 또한, 양자 내성 암호(포스트 양자 암호) 연구가 활발히 진행 중이며, 미래의 양자컴퓨터 위협에 대비하고 있습니다. 따라서 "현재" 모든 암호화 시스템을 무력화할 수 있다는 주장은 과장된 표현입니다.

# %%
# 요청사항 테스트
response = chain.invoke({
        "text": "파이썬으로 간단한 웹 스크래퍼를 만들고 싶습니다."
})
print(response)
# Out:
# 유형: 요청사항
# 내용: 파이썬으로 간단한 웹 스크래퍼를 만드는 방법을 단계별로 설명드리겠습니다.
#
# 1. 필요한 라이브러리 설치
#    - `requests`: 웹 페이지의 HTML을 가져오기 위해 사용
#    - `BeautifulSoup`: HTML을 파싱하여 원하는 데이터를 추출하기 위해 사용
#    ```bash
#    pip install requests beautifulsoup4
#    ```
#
# 2. 웹 페이지 요청 및 HTML 가져오기
#    ```python
#    import requests
#
#    url = 'https://example.com'  # 스크래핑할 웹 페이지 URL
#    response = requests.get(url)
#    html = response.text
#    ```
#
# 3. HTML 파싱 및 데이터 추출
#    ```python
#    from bs4 import BeautifulSoup
#
#    soup = BeautifulSoup(html, 'html.parser')
#    # 예: 모든 <a> 태그의 텍스트와 링크 추출
#    for link in soup.find_all('a'):
#        print(link.get_text(), link.get('href'))
#    ```
#
# 4. 결과 저장 또는 활용
#    - 추출한 데이터를 파일로 저장하거나 다른 용도로 활용할 수 있습니다.
#
# 5. 주의사항
#    - 웹사이트의 robots.txt 파일을 확인하여 스크래핑이 허용되는지 확인하세요.
#    - 과도한 요청은 서버에 부담을 줄 수 있으니 적절한 딜레이를 두세요.
#
# 이 과정을 통해 간단한 웹 스크래퍼를 만들 수 있습니다. 필요에 따라 더 복잡한 기능도 추가 가능합니다.

# %% [markdown]
# ---
#
# # **프롬프트 엔지니어링 개념**
#
# 1. **개념**:
#     - AI 모델에게 효과적인 지시를 제공하여 원하는 결과를 얻어내는 기술
#     - 입력(프롬프트)을 최적화하여 출력의 품질을 향상하는 방법
#
# 2. **원칙**:
#
#     1. **명확성(Clarity)**
#
#
#     2. **맥락성(Context)**
#
#
#     3. **구조화(Structure)**

# %% [markdown]
# ---
# ## 1. **명확성(Clarity)**
#
# - **프롬프트의 명확성**은 AI 모델과의 효과적인 소통을 위한 핵심 요소
#
# - 불필요한 내용을 제외하고 **핵심 요구사항**에만 집중하여 작성
#
# - 원하는 결과물에 대해 **구체적이고 정확한 지시**를 제공
# - 모호하지 않은 명확한 지시사항 제공
# - 구체적인 요구사항과 제약조건 명시
# - 예시: "5개의 짧은 문장으로 요약해주세요" vs "요약해주세요"

# %%
from langchain_core.prompts import PromptTemplate

# 명확한 지시사항이 포함된 프롬프트 템플릿
clear_prompt = PromptTemplate(
    input_variables=["topic"],
    template="""
    주제: {topic}
    
    다음 기준을 반드시 준수하여 설명하시오:
    1. 정확히 3문장으로 작성할 것 (Bullet point 사용하여 구분)
    2. 각 문장은 20단어 이내로 작성할 것
    3. 전문 용어는 괄호 안에 간단한 설명을 포함할 것
    """
)

# LCEL 체인
clear_chain = clear_prompt | llm 

# 테스트
result = clear_chain.invoke({"topic": "인공지능"})
pprint(result.content)
# Out:
# ('- 인공지능은 컴퓨터가 인간처럼 학습하고 문제를 해결하는 기술을 의미한다.  \n'
#  '- 머신러닝(데이터로부터 학습하는 알고리즘)은 인공지능의 핵심 분야 중 하나이다.  \n'
#  '- 인공지능은 의료, 자율주행, 음성인식 등 다양한 산업에서 혁신을 이끌고 있다.')

# %% [markdown]
# ---
# ## 2. **맥락성(Context)**
#
# - **맥락 제공**은 AI가 작업의 배경과 목적을 이해하는데 필수적인 요소
#
# - 프롬프트에 **배경 정보**, **목적**, **대상 환경**을 명확히 포함
#
# - 적절한 맥락 제공은 AI의 **출력 품질**과 **정확도**를 크게 향상
# - 관련 배경 정보 제공 -> 확률분포 범위를 줄임
# - 목적과 의도 명시
# - 대상 독자나 사용 환경 설명

# %%
from langchain_core.prompts import ChatPromptTemplate

# 맥락이 부족한 프롬프트의 예
bad_prompt = ChatPromptTemplate.from_template("""
당신은 친절한 AI 어시스턴트입니다. 사용자의 질문에 답변해주세요.
사용자 질문: {user_question}                                              
""")

# 맥락이 풍부한 프롬프트의 예
good_prompt = ChatPromptTemplate.from_template("""
사용자 질문: {user_question}

배경: 65세 이상 노인을 대상으로 하는 스마트폰 교육 프로그램을 진행하고 있습니다.
목적: 처음 스마트폰을 사용하는 노인들이 기본 기능을 쉽게 익힐 수 있도록 돕고자 합니다.
대상: 디지털 기기 사용 경험이 거의 없는 노인입니다.

위 맥락을 고려하여 응답해주세요.

응답 형식:
- 쉬운 용어 사용
- 단계별 설명
- 구체적인 예시 포함
""")


# LCEL 체인
good_chain = good_prompt | llm 
bad_chain = bad_prompt | llm

# 테스트
question = "아이폰에 카카오톡 설치하는 방법을 알려주세요."
good_result = good_chain.invoke({"user_question": question})
bad_result = bad_chain.invoke({"user_question": question})

print("맥락이 부족한 프롬프트의 결과")
pprint(bad_result.content)
print("-"*100)

print("맥락이 풍부한 프롬프트의 결과")
pprint(good_result.content)
# Out:
# 맥락이 부족한 프롬프트의 결과
# ('아이폰에 카카오톡을 설치하는 방법을 안내해드릴게요.\n'
#  '\n'
#  '1. **앱스토어 열기**  \n'
#  '   아이폰에서 홈 화면에 있는 **App Store** 아이콘을 탭하여 앱스토어를 엽니다.\n'
#  '\n'
#  '2. **검색하기**  \n'
#  '   하단의 돋보기 모양 아이콘(검색)을 탭한 후, 검색창에 **"카카오톡"**을 입력하고 검색합니다.\n'
#  '\n'
#  '3. **카카오톡 선택**  \n'
#  '   검색 결과에서 **카카오톡(KakaoTalk)** 앱을 찾아 탭합니다. 개발사는 "Kakao Corp."입니다.\n'
#  '\n'
#  '4. **설치하기**  \n'
#  '   **받기** 또는 클라우드 모양 아이콘을 탭하여 다운로드 및 설치를 시작합니다. Apple ID 비밀번호를 묻거나 Face '
#  'ID/Touch ID 인증을 요청할 수 있습니다.\n'
#  '\n'
#  '5. **설치 완료 후 열기**  \n'
#  '   설치가 완료되면 **열기** 버튼을 눌러 카카오톡을 실행합니다.\n'
#  '\n'
#  '6. **회원가입 또는 로그인**  \n'
#  '   기존 계정이 있으면 로그인하고, 없으면 회원가입 절차를 따라 계정을 만드시면 됩니다.\n'
#  '\n'
#  '필요하시면 추가로 카카오톡 사용법도 알려드릴 수 있습니다!')
# ----------------------------------------------------------------------------------------------------
# 맥락이 풍부한 프롬프트의 결과
# ('안녕하세요! 아이폰에 카카오톡을 설치하는 방법을 아주 쉽게 알려드릴게요. 천천히 따라 하시면 누구나 할 수 있어요.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 아이폰에 카카오톡 설치하는 방법\n'
#  '\n'
#  '#### 1단계: 아이폰에서 ‘앱스토어’ 찾기  \n'
#  '- 아이폰 바탕화면에서 **파란색 글자 A 모양 아이콘**을 찾아서 눌러요.  \n'
#  '- 이 앱이 ‘앱스토어’예요. 여기서 여러 가지 앱을 받을 수 있어요.\n'
#  '\n'
#  '#### 2단계: 앱스토어에서 ‘카카오톡’ 검색하기  \n'
#  '- 앱스토어가 열리면, 아래쪽에 돋보기 모양(🔍)이 있어요. 그걸 눌러요.  \n'
#  '- 위에 흰색 칸이 나오면, 거기에 ‘카카오톡’이라고 천천히 써보세요.  \n'
#  '- ‘카카오톡’이 검색 결과에 나타나면, 그걸 눌러요.\n'
#  '\n'
#  '#### 3단계: 카카오톡 앱 설치하기  \n'
#  '- ‘카카오톡’ 앱 옆에 ‘받기’ 또는 구름 모양 아이콘이 보여요.  \n'
#  '- ‘받기’를 누르면, 아이폰이 앱을 다운로드(다운로드는 ‘내려받기’라는 뜻이에요)하기 시작해요.  \n'
#  '- 설치가 끝나면 ‘열기’라는 버튼이 생겨요.\n'
#  '\n'
#  '#### 4단계: 카카오톡 앱 열기  \n'
#  '- ‘열기’를 눌러서 카카오톡을 실행해요.  \n'
#  '- 처음 실행할 때는 ‘동의’나 ‘허용’ 버튼이 나올 수 있어요. 모두 ‘예’ 또는 ‘허용’을 눌러주세요.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 참고  \n'
#  '- 만약 ‘애플 아이디’ 비밀번호를 물어보면, 아이폰을 처음 사용할 때 만든 비밀번호를 입력하세요.  \n'
#  '- 설치가 어려우면, 주변 가족이나 선생님께 도움을 요청해도 좋아요.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '이렇게 하면 아이폰에 카카오톡이 설치되어 친구들과 편하게 메시지를 주고받을 수 있어요!  \n'
#  '천천히, 차근차근 따라 해보세요. 궁금한 점 있으면 언제든 물어보세요!')

# %% [markdown]
# ---
# ## 3. **구조화(Structure)**
#
# - 체계적인 형식 사용
# - 단계별 지시사항 제공
#
# - 프롬프트 입력의 구조화: PromptTemplate, ChatPromptTemplate 사용
#     - PromptTemplate
#         - **프롬프트 템플릿**은 LLM과의 상호작용을 구조화하는 핵심 도구
#         - 템플릿은 다양한 입력값으로 **재사용**이 가능하며 **유연한 변수 처리**를 지원
#         - **검증 기능**과 **부분 포맷팅**을 통해 프롬프트 작성의 안정성을 보장
#     - ChatPromptTemplate
#         - **챗 프롬프트 템플릿**은 대화형 AI와의 상호작용을 위한 특화된 템플릿
#         - 시스템/사용자/어시스턴트 등 **다양한 역할**의 메시지를 구조화
#         - 대화의 **맥락과 흐름**을 유지하면서 일관된 상호작용 가능
# - 원하는 출력 형식 명시 = LLM 출력의 구조화: OutputParser, Schema 사용
#
# - 기대효과:
#     - 일관된 형식의 입출력 보장
#     - 데이터 처리 및 후속 작업의 용이성
#     - 오류 처리의 체계화
#     - 재사용성 향상

# %% [markdown]
# ### 1) 프롬프트 입력의 구조화

# %% [markdown]
# #### 1-a) 프롬프트 템플릿 (Prompt Template)

# %% [markdown]
# `(1) 기본 템플릿`

# %%
from langchain_core.prompts import PromptTemplate

# 템플릿 정의
template = """
다음 주제에 대해 설명해주세요: {topic}
포함해야 할 내용: {content}
글자수: {length}
"""

prompt = PromptTemplate(
    template=template,
    input_variables=["topic", "content", "length"]
)

# 템플릿 사용
formatted_prompt = prompt.format( # LLM에 보내기 전에, 변수가 채워진 최종 프롬프트가 어떻게 생겼는지 확인(미리보기)하는 함수
    topic="인공지능",
    content="정의, 역사, 응용분야",
    length="500자"
)

print(formatted_prompt)
# Out:
# 다음 주제에 대해 설명해주세요: 인공지능
# 포함해야 할 내용: 정의, 역사, 응용분야
# 글자수: 500자

# %% [markdown]
# `(2) from_template 메소드`

# %%
from langchain_core.prompts import PromptTemplate

# 템플릿 문자열 정의
template = """
다음 주제에 대해 설명해주세요: {topic}
포함해야 할 내용: {content}
글자수: {length}
"""

# 템플릿 생성 (템플릿 문자열 지정)
prompt = PromptTemplate.from_template(template)

# 템플릿 사용 (입력 변수 지정)
formatted_prompt = prompt.format(
    topic="인공지능",
    content="정의, 역사, 응용분야",
    length="500자"
)

print(formatted_prompt)
# Out:
# 다음 주제에 대해 설명해주세요: 인공지능
# 포함해야 할 내용: 정의, 역사, 응용분야
# 글자수: 500자

# %% [markdown]
# `(3) 템플릿 검증 및 부분 포맷팅`

# %%
from langchain_core.prompts import PromptTemplate

# 템플릿 생성 
template = PromptTemplate(
    template="{product}의 다음 특징을 분석해주세요: {feature}",  # 템플릿 문자열
    input_variables=["product", "feature"],  # 입력 변수 목록
    validate_template=True  # 템플릿 유효성 검증
)

# 부분적으로 변수 채우기
partial_prompt = template.partial(product="스마트폰")

print(f"부분적으로 변수 채워진 템플릿: {partial_prompt}")
print("-"*100)

# 나중에 나머지 변수 채우기
final_prompt1 = partial_prompt.format(feature="카메라")

print(f"나머지 변수 채워진 템플릿: {final_prompt1}")
print("-"*100)

# 다른 특징을 분석하도록 변수 변경
final_prompt2 = partial_prompt.format(feature="배터리 수명")

print(f"다른 변수 채워진 템플릿: {final_prompt2}")
print("-"*100)

# 모든 변수를 한 번에 채우기
final_prompt3 = template.format(product="노트북", feature="배터리 수명")

print(f"모든 변수 채워진 템플릿: {final_prompt3}")
# Out:
# 부분적으로 변수 채워진 템플릿: input_variables=['feature'] input_types={} partial_variables={'product': '스마트폰'} template='{product}의 다음 특징을 분석해주세요: {feature}' validate_template=True
# ----------------------------------------------------------------------------------------------------
# 나머지 변수 채워진 템플릿: 스마트폰의 다음 특징을 분석해주세요: 카메라
# ----------------------------------------------------------------------------------------------------
# 다른 변수 채워진 템플릿: 스마트폰의 다음 특징을 분석해주세요: 배터리 수명
# ----------------------------------------------------------------------------------------------------
# 모든 변수 채워진 템플릿: 노트북의 다음 특징을 분석해주세요: 배터리 수명

# %%
# 템플릿 유효성 검증 실패
try:
    invalid_prompt = template.format(product="스마트폰")
except ValueError as e:
    print(f"템플릿 유효성 검증 실패: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 # 템플릿 유효성 검증 실패
#       2 try:
# ----> 3     invalid_prompt = template.format(product="스마트폰")
#       4 except ValueError as e:
#       5     print(f"템플릿 유효성 검증 실패: {e}")
#
# File ~/edu/001_chatbot/.venv/lib/python3.11/site-packages/langchain_core/prompts/prompt.py:201, in PromptTemplate.format(self, **kwargs)
#     192 """Format the prompt with the inputs.
#     193
#     194 Args:
#    (...)    198     A formatted string.
#     199 """
#     200 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 201 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-x86_64-none/lib/python3.11/string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File ~/edu/001_chatbot/.venv/lib/python3.11/site-packages/langchain_core/utils/formatting.py:48, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      43     msg = (
#      44         "No arguments should be provided, "
#      45         "everything should be passed as keyword arguments."
#      46     )
#      47     raise ValueError(msg)
# ---> 48 return super().vformat(format_string, args, kwargs)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-x86_64-none/lib/python3.11/string.py:194, in Formatter.vformat(self, format_string, args, kwargs)
#     192 def vformat(self, format_string, args, kwargs):
#     193     used_args = set()
# --> 194     result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
#     195     self.check_unused_args(used_args, args, kwargs)
#     196     return result
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-x86_64-none/lib/python3.11/string.py:234, in Formatter._vformat(self, format_string, args, kwargs, used_args, recursion_depth, auto_arg_index)
#     230     auto_arg_index = False
#     232 # given the field_name, find the object it references
#     233 #  and the argument it came from
# --> 234 obj, arg_used = self.get_field(field_name, args, kwargs)
#     235 used_args.add(arg_used)
#     237 # do any conversion on the resulting object
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-x86_64-none/lib/python3.11/string.py:299, in Formatter.get_field(self, field_name, args, kwargs)
#     296 def get_field(self, field_name, args, kwargs):
#     297     first, rest = _string.formatter_field_name_split(field_name)
# --> 299     obj = self.get_value(first, args, kwargs)
#     301     # loop through the rest of the field_name, doing
#     302     #  getattr or getitem as needed
#     303     for is_attr, i in rest:
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-x86_64-none/lib/python3.11/string.py:256, in Formatter.get_value(self, key, args, kwargs)
#     254     return args[key]
#     255 else:
# --> 256     return kwargs[key]
#
# KeyError: 'feature'

# %% [markdown]
# #### 1-b) 챗 프롬프트 템플릿 (Chat Prompt Template)

# %% [markdown]
# `(1) 메시지 템플릿 사용`

# %%
### 복잡한 템플릿 구성

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate

# 개별 메시지 템플릿 생성
system_message = SystemMessagePromptTemplate.from_template(
    "당신은 {role} 전문가입니다. {style} 스타일로 답변해주세요."
)

human_message = HumanMessagePromptTemplate.from_template(
    "{question}"
)

# from_messages 메소드 사용 (여러 개의 메시지들을 원소로 갖는 리스트로 구성)
chat_prompt = ChatPromptTemplate.from_messages([
    system_message,
    human_message
])

# 템플릿 사용
formatted_prompt = chat_prompt.format(
    role="인공지능",
    style="친절한",
    question="인공지능의 정의를 설명해주세요."
)

print(formatted_prompt)
# Out:
# System: 당신은 인공지능 전문가입니다. 친절한 스타일로 답변해주세요.
# Human: 인공지능의 정의를 설명해주세요.

# %% [markdown]
# `(2) 문자열 템플릿 사용`

# %%
from langchain_core.prompts import ChatPromptTemplate

# 시스템 메시지와 사용자 메시지를 포함한 템플릿 정의
template = """
당신은 {role} 전문가입니다. {style} 스타일로 답변해주세요.

{question}
"""

# from_template 메소드 사용 (단일 템플릿 문자열 직접 사용)
chat_prompt = ChatPromptTemplate.from_template(template)

# 템플릿 사용
formatted_prompt = chat_prompt.format(
    role="인공지능",
    style="친절한",
    question="인공지능의 정의를 설명해주세요."
)

# ChatPromptTemplate을 직접 생성 - 이때는 HumanMessage로 처리됨 (SystemMessage는 별도로 추가해야 함)
print(formatted_prompt)
# Out:
# Human:
# 당신은 인공지능 전문가입니다. 친절한 스타일로 답변해주세요.
#
# 인공지능의 정의를 설명해주세요.

# %% [markdown]
# ### 2)  LLM 출력의 구조화
# #### 2-a) OutputParser 활용
#
# - **OutputParser**는 LLM의 출력을 다양한 데이터 형식으로 변환하는 도구
#
# - **문자열**, **JSON**, **XML** 등 여러 형식의 파싱을 지원
#
# - 파싱된 출력은 **다른 시스템**이나 **프로세스**와 연동하는데 유용

# %% [markdown]
# `(1) JSONOutputParser`
# - LLM의 출력을 **구조화된 JSON**으로 변환
# - 파서는 출력의 **데이터 유효성**을 검증하고 일관된 형식을 보장

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel, Field
from typing import List

# 관광지 정보를 위한 Pydantic 모델 정의 (이름, 위치, 카테고리, 주요 관람 포인트)
class TouristSpot(BaseModel):
    name: str = Field(description="관광명소 이름")
    location: str = Field(description="위치 (구/동 정보)")
    category: str = Field(description="카테고리 (궁궐/박물관/쇼핑 등)")
    highlights: List[str] = Field(description="주요 관람 포인트")

# JsonOutputParser 파서 설정 (Pydantic 모델 지정)
parser = JsonOutputParser(pydantic_object=TouristSpot)

# parser의 get_format_instructions 메소드 사용 (포맷 지시사항 출력)
pprint(parser.get_format_instructions())

# %%
# 프롬프트 템플릿 정의 (parser의 get_format_instructions 메소드 사용)
prompt = PromptTemplate(
    template="""서울의 다음 관광명소에 대한 상세 정보를 제공해주세요.
{format_instructions}

관광지: {spot_name}
""",
    input_variables=["spot_name"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# 완성된 프롬프트 템플릿 출력 (포맷 지시사항 포함)
pprint(prompt.format(spot_name="경복궁"))

# %%
# 체인 구성
chain = prompt | llm | parser

# 실행 예시
result = chain.invoke({
    "spot_name": "경복궁"
})

# 결과 출력
pprint(result)

# %% [markdown]
# `(2) XMLOutputParser`
# - LLM의 출력을 **구조화된 XML** 형식으로 변환
# - XML 구조는 **계층적 데이터**를 표현하는데 효과적
# - 패키지 설치: defusedxml

# %%
from langchain_core.output_parsers import XMLOutputParser

# XML 파서 설정 - 원하는 태그 구조 정의
parser = XMLOutputParser(tags=["tourist_spot", "name", "location", "category", "highlights", "point"])

# parser의 get_format_instructions 메소드 사용 (포맷 지시사항 출력)
pprint(parser.get_format_instructions())

# %%
# 프롬프트 템플릿 정의
prompt = PromptTemplate(
    template="""서울의 다음 관광명소에 대한 상세 정보를 XML 형식으로 제공해주세요.
{format_instructions}

관광지: {spot_name}""",
    input_variables=["spot_name"],
    partial_variables={"format_instructions": parser.get_format_instructions()}  
)

# 완성된 프롬프트 템플릿 출력 (포맷 지시사항 포함)
pprint(prompt.format(spot_name="경복궁"))

# %%
# 체인 구성
chain = prompt | llm | parser

# 실행 예시
result = chain.invoke({
    "spot_name": "경복궁"
})

# 결과는 Python 딕셔너리 형태로 파싱되어 반환됨 
pprint(result)

# %%
# XML 형식의 결과를 다시 파싱하여 출력 (가장 상위 태그를 제외한 내용만 출력)
result['tourist_spot']

# %%
# 방법1) 인덱스로 직접 접근
highlights = result['tourist_spot'][3]['highlights']  # index 3번째가 highlights

for h in highlights:
    print(h['point'])

# %%
# 방법2) 동적으로 찾기 (더 안전 ✅) <- 인덱스 위치가 바뀔 수 있으므로, highlights 키를 가진 항목을 찾아서 접근
for item in result['tourist_spot']:
    if 'highlights' in item:
        for h in item['highlights']:
            print(h['point'])

# %% [markdown]
# #### 2-b) `사용자 정의(Custom) OutputParser`
#
# - **사용자 정의 파서**는 **RunnableLambda**나 **RunnableGenerator**를 활용하여 구현
# - 특정 비즈니스 요구사항에 맞는 **맞춤형 출력 형식**을 정의할 수 있음
# - 복잡한 **데이터 변환**과 **후처리 로직**을 유연하게 구현할 수 있음

# %%
from langchain_core.messages import AIMessage
from langchain_core.prompts import PromptTemplate
from typing import Dict

# 사용자 정의 파서
# 함수 자체가 Runnable인 게 아니라, | 파이프에 연결되는 순간 LangChain이 RunnableLambda로 자동 감싸서 Runnable로 만들어줌
# RunnableLambda를 명시적으로 쓰는 건 '자동으로 해주는 걸 내가 직접 하겠다'는 것뿐이에요
def parse_tourist_spot(ai_message: AIMessage) -> Dict:
    """관광지 정보를 딕셔너리로 파싱"""
    lines = ai_message.content.split('\n')
    return {
        "name": lines[0] if lines else "",
        "description": ' '.join(lines[1:]) if len(lines) > 1 else ""
    }

# 프롬프트 템플릿
prompt = PromptTemplate(
    template="다음 관광지에 대해 첫 줄에 이름, 다음 줄부터 설명을 100자 내외로 작성해주세요:\n{spot_name}",
    input_variables=["spot_name"]
)

# 체인 구성 (invoke 방식)
# 방법1) 여기서 자동으로 Runnable로 변환됨
invoke_chain = prompt | llm | parse_tourist_spot
#                             ↑ LangChain이 내부적으로 RunnableLambda로 자동 감싸줌

# 방법2) 명시적으로 Runnable로 만들기
# RunnableLambda = 전체 출력이 완성된 후 처리
# parser = RunnableLambda(parse_tourist_spot)
# chain = prompt | llm | parser  # 이제 명시적으로 Runnable

# 체인 실행
result = invoke_chain.invoke({
    "spot_name": "경복궁"
})

pprint(result)

# %% [markdown]
# RunnableLambda   : LLM 완성 → 파서 처리 → 출력
#
#                    [██████████] 다 받고 나서 처리
#
# RunnableGenerator: LLM 생성 중 → 조금씩 처리 → 조금씩 출력
#
#                    [█] → [██] → [███] → 실시간 처리

# %%
## 위 구현을 stream 방식으로 변경

from langchain_core.runnables import RunnableGenerator
from langchain_core.messages import AIMessageChunk
from typing import Iterable
import time

# 사용자 정의 파서 (stream 방식) 
def streaming_parse_tourist_spot(chunks: Iterable[AIMessageChunk]) -> Iterable[str]:
    """실시간으로 관광지 정보 파싱"""
    for chunk in chunks:
        yield f"🏛 {chunk.content}"   # 🏛 이모지 추가 

# stream 방식 체인 구성 <- RunnableGenerator = 스트리밍용 파서, LLM이 토큰을 생성하는 동안 실시간으로 처리
streaming_chain = prompt | llm | RunnableGenerator(streaming_parse_tourist_spot)

# 체인 실행 
for chunk in streaming_chain.stream({"spot_name": "광화문"}):
    print(chunk)
    time.sleep(0.1)   # 시간 지연 추가

# %% [markdown]
# **[참고] 이모지(emoji) 입력 방법**
#
# 1. Windows에서:
#     - `Windows 키 + .` (윈도우 키와 마침표를 동시에 누름)
#     - 또는 `Windows 키 + ;` (윈도우 키와 세미콜론을 동시에 누름)
#
# 2. Mac에서:
#     - `fn(지구본) 키 + E`

# %% [markdown]
# #### 2-c) `구조화된 출력 프롬프트 (Structured Output Prompts)`
#    - 일관된 형식의 응답
#    - 데이터 처리 용이

# %%
# typing 사용, 파이썬 표준 라이브러리, 단순히 딕셔너리 구조를 문서화하고 싶을 때(가볍게)
from typing import TypedDict, Annotated 

class AnalysisResult(TypedDict):
    """분석 결과 스키마"""
    summary: Annotated[str, ..., "핵심 요약"]
    keywords: Annotated[list[str], ..., "주요 키워드"]
    sentiment: Annotated[str, ..., "긍정/부정/중립"]

structured_llm = llm.with_structured_output(AnalysisResult)
# LangChain이 내부적으로 하는 일 = LangChain이 내부적으로 OpenAI API에 이렇게 요청함
# {
#   "model": "gpt-4o-mini",
#   "tools": [{                      ← OpenAI Tool Calling 기능 활용
#     "type": "function",
#     "function": {
#       "name": "TouristSpot",
#       "parameters": { ... }        ← Pydantic schema를 JSON schema로 변환
#     }
#   }],
#   "tool_choice": "required"
# }

# LCEL
chain = step_prompt | structured_llm

# 질문
text = """
양자 컴퓨팅은 양자역학의 원리를 바탕으로 데이터를 처리하는 새로운 형태의 계산 방식이다.
기존의 고전적 컴퓨터는 0과 1로 이루어진 이진법(bit)을 사용하여 데이터를 처리하지만,
양자 컴퓨터는 양자 비트(큐비트, qubit)를 사용하여 훨씬 더 복잡하고 빠른 계산을 수행할 수 있다.

큐비트는 동시에 0과 1의 상태를 가질 수 있는 양자 중첩(superposition) 상태를 활용하며,
이를 통해 병렬 계산과 같은 고급 기능이 가능하다.
"""

output = chain.invoke({"text": text})
pprint(output)

# %%
# pydantic 사용
from typing import List, Literal
from pydantic import BaseModel, Field # 외부 라이브러리로써, 실제 데이터 검증, LLM 구조화 출력, API 요청/응답 등(실용적), 더 추천 ✅ (검증 + 자동완성)

class AnalysisResult(BaseModel):
    """텍스트 분석 결과를 담는 스키마"""
    
    summary: str = Field(
        ...,  # ... 은 required 필드를 의미 (필수 입력, None 허용 안함)
        description="텍스트의 핵심 내용 요약"
    )
    
    keywords: List[str] = Field(
        ...,
        description="텍스트에서 추출한 주요 키워드"
    )
    
    sentiment: Literal["긍정", "부정", "중립"] = Field(
        ...,
        description="텍스트의 전반적인 감정 분석 결과"
    )

structured_llm = llm.with_structured_output(AnalysisResult)

# LCEL
chain = step_prompt | structured_llm

# 질문
output = chain.invoke({"text": text})
print(output)
print(type(output)) # <class '__main__.AnalysisResult'>
print("-"*100)
print(output.summary)
print(output.keywords)
print(output.sentiment)

# %% [markdown]
# cf. Literal = 타입에 "이 값들 중에서만 골라라" 라고 선택지를 딱 제한해주는 타입, 마치 드롭다운 메뉴처럼 -> LM 출력을 구조화할 때, AI가 정해진 값 외의 다른 말을 못 하도록 강제함

# %% [markdown]
# ---
#
# # [실습 프로젝트]
#
# ### 맞춤형 학습 도우미 챗봇 만들기
#
# - 특정 주제에 대한 학습을 돕는 챗봇을 만들어봅니다. 앞서 배운 프롬프트 유형들을 조합하여 활용합니다.
#
# - (1) 퀴즈 문제 예시를 보고, (2) 개념 설명 체인을 완성합니다.

# %% [markdown]
# `(1) 퀴즈 문제 출제 (예시)`

# %%
from typing import List
from pydantic import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# 퀴즈 문제 스키마
class QuizQuestion(BaseModel):
    """퀴즈 문제 스키마"""
    question: str = Field(..., description="퀴즈 문제")
    options: List[str] = Field(..., description="보기 (4개)")
    correct_answer: int = Field(..., description="정답 번호 (1-4)")
    explanation: str = Field(..., description="정답 설명")


# 퀴즈 생성을 위한 구조화된 출력 프롬프트
quiz_prompt = PromptTemplate(
    template="""다음 주제에 대한 퀴즈 문제를 만들어주세요:
    
주제: {topic}
난이도(상/중/하): {difficulty}

다음 조건을 만족하는 퀴즈를 생성해주세요:
1. 문제는 명확하고 이해하기 쉽게
2. 4개의 보기 제공
3. 정답과 오답은 비슷한 수준으로
4. 상세한 정답 설명 포함""",
    input_variables=["topic", "difficulty"]
)

# LLM 정의
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.3)

# 구조화된 출력 파서 설정
structured_llm = llm.with_structured_output(QuizQuestion)

# LCEL 체인 구성
chain = quiz_prompt | structured_llm

# 질문 실행
output = chain.invoke({"topic": "인공지능", "difficulty": "상"})

# 결과 출력
pprint(f"퀴즈 문제: {output.question}")
pprint(f"보기: {output.options}")
pprint(f"정답: {output.correct_answer}")
pprint(f"정답 설명: {output.explanation}")

# %% [markdown]
# `(2) 개념 설명 체인 (문제)`

# %%
# 개념 설명을 위한 스키마
class ConceptExplanation(BaseModel):
    """개념 설명 스키마"""
    topic: str = Field(..., description="설명 대상 개념")
    explanation: str = Field(..., description="개념 설명")
    examples: str = Field(..., description="구체적인 예시")
    related_concepts: List[str] = Field(..., description="관련 개념 (3개)")

# 개념 설명을 위한 지시형 프롬프트
concept_prompt = PromptTemplate(
    template="""다음 개념을 설명해 주세요:

    주제: {topic}
    난이도(상/중/하): {difficulty}

    다음 조건을 만족하도록 설명해 주세요:
    1. 난이도에 적합한 설명
    2. 개념 정의로 시작, 필요한 경우 수식도 포함
    3. 구체적인 예시 제공, 이 때 스토리텔링으로 설명
    4. 관련 개념 3가지 제시""",
    input_variables=["topic", "difficulty"]
)

# 구조화된 출력 파서 설정
structured_llm = llm.with_structured_output(ConceptExplanation)

# LCEL 체인 구성
chain = concept_prompt | structured_llm

# 질문 실행
output = chain.invoke({"topic": "인공지능", "difficulty": "하"})

# 결과 출력
pprint(f"주제: {output.topic}")
pprint(f"설명: {output.explanation}")
pprint(f"예시: {output.examples}")
pprint(f"관련 개념: {output.related_concepts}")
